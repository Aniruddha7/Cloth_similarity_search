# %% [markdown]
# #Web scraping mens cloths from asos.com

# %%
#Requests and URL

import requests
import pandas as pd

#As we are scraping the data from multiple pages, create empty lists to store the data respectively.
product_name=[]
category=[]
current_price=[]
brand_name=[]
Url=[]
website_link='https://www.asos.com/'

#In the wesite a single page has 72 products listed, hence iterate over 40 such pages to scrape the data
for i in range (0,2160,72):

  cookies = {
      'asosAffiliate': 'affiliateId=17295',
      'browseCountry': 'IN',
      's_ecid': 'MCMID%7C36348881506979124243080375041297881048',
      'browseCurrency': 'GBP',
      'browseLanguage': 'en-GB',
      'browseSizeSchema': 'UK',
      'storeCode': 'ROW',
      'currency': '1',
      'featuresId': 'add09538-59a0-4fa6-8f7f-ca531bef34bf',
      '_gcl_au': '1.1.1976705817.1684424031',
      'bt_stdstatus': 'NOTSTUDENT',
      'stc-welcome-message': 'cappedPageCount=2',
      'floor': '1001',
      'asos': 'PreferredSite=&currencyid=1&currencylabel=GBP&customerguid=b491a3e6606e47db8edb1abf9b54f05e&topcatid=1001',
      '_cs_c': '0',
      'FPID': 'FPID2.2.55wejNiJBlk6Fjma5ucw%2Fvvp23W6qvL6uTzByYWrvjA%3D.1684424040',
      'FPAU': '1.1.1976705817.1684424031',
      '_gid': 'GA1.2.2055111386.1684424054',
      '__gads': 'ID=9c6f643b4ee7c6ba:T=1684424534:S=ALNI_MYCZva9KxAitInZFVy_700g-uExxw',
      'fita.sid.asos': 'ax09Qz461ZBFRGcMmoIZOeGWfCgIwlUT',
      'geocountry': 'IN',
      'bm_sz': '6F4E5D165BA708EEEC4011BA861BCA66~~4470576~3753525',
      'asos-b-sdv629': 'ornjx7v-36',
      'AMCVS_C0137F6A52DEAFCC0A490D4C%40AdobeOrg': '1',
      'asos-perx': 'b491a3e6606e47db8edb1abf9b54f05e||204f4c0f389049b2b24dc76eac6ada44',
      's_cc': 'true',
      'FPLC': 'S%2F0sQv30QhK5inMdjhyDMHVjSgBkk5C4hGiZ%2FgdxKFkRtVIY374OncSqDkxoitBs9LM1lOPyLJp5l%2FbpDoKUzj7kJ7Wg2XfiP6twIJd9pwSX2D%2FVhdQ%2FkEYdCWH98Q%3D%3D',
      '__gpi': 'UID=00000c07c4305ff8:T=1684424534:RT=1684503731:S=ALNI_MaVBVf5JJhPC5Y43gQd2g1BsZS52g',
      'siteChromeVersion': 'au=12&com=12&de=12&dk=12&es=12&fr=12&it=12&nl=12&pl=12&roe=12&row=12&ru=12&se=12&us=12',
      'keyStoreDataversion': 'ornjx7v-36',
      'AMCV_C0137F6A52DEAFCC0A490D4C%40AdobeOrg': '-1303530583%7CMCMID%7C36348881506979124243080375041297881048%7CMCAAMLH-1685119361%7C12%7CMCAAMB-1685119361%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCCIDH%7C0%7CMCOPTOUT-1684521761s%7CNONE%7CvVersion%7C3.3.0%7CMCAID%7CNONE',
      '_s_fpv': 'true',
      '_abck': '842C1A26B79B39231A32A645DB911DDA~0~...~-1~-1~1684518051',
      '_cs_mk_aa': '0.7674853226137397_1684514587414',
      'bm_mi': '14AA33748C7244C5D3F97E0D33529145~~1',
      'bm_sv': '60C5FB35221D7619DE4DBD93420EAA2C~YAAQpLxWaBrBBAaIAQAAo+LqNBNI+MXPjPYpkk63FNovbqLTagoTDpfQ2ImULZvjcgQPz0apV19GDiS3df44TJVJ4StBT479BaSq3Cr5OewSBiYJWzGU4ey6AG0wRd1fLTY1cjjKCaqWBDYcPIXg0a8tBziQonygxvTO0U119kjVeCLoJAXhlDRWl68177Fm//YGODLMXYCygIxpUP/pOnxQziUMtN6nRPdsIe3xeTPqGoGr6mihya13a3MgCg==~1',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Fri+May+19+2023+22%3A20%3A49+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&landingPath=https%3A%2F%2Fwww.asos.com%2Fmen%2Fsale%2Fcat%2F%3Fcid%3D8409&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1',
      '_ga': 'GA1.2.106621371.1684424040',
      'plp_columsCount': 'threeColumns',
      '_ga_1JR0QCFRSY': 'GS1.1.1684514589.6.1.1684515130.45.0.0',
      'ak_bmsc': 'C08DDC448B069F1F58F4044A8B9DB46E~000000000000000000000000000000~...',
      '_cs_id': '3590dd81-5708-aaac-8054-eebeb4055e8e.1684424039.6.1684515131.1684514589.1628755191.1718588039920',
      '_cs_s': '9.0.0.1684516931985',
      's_pers': '%20s_vnum%3D1685557800193%2526vn%253D7%7C1685557800193%3B%20gpv_eVar230%3Dno%2520value%7C1684516410299%3B%20gpv_eVar234%3Dno%2520value%7C1684516410306%3B%20gpv_p6%3D%2520%7C1684516837095%3B%20s_nr%3D1684515057951-Repeat%7C1716051057951%3B%20gpv_e47%3Dno%2520value%7C1684516857960%3B%20gpv_p10%3Ddesktop%2520row%257Ccategory%2520page%257C8409%2520refined%7C1684516857974%3B%20gpv_e231%3Dfa43ec7e-eaae-419d-8571-5880f210b75b%7C1684516932177%3B%20eVar225%3D7%7C1684516932253%3B%20s_invisit%3Dtrue%7C1684516932263%3B%20visitCount%3D7%7C1684516932270%3B',
      'RT': '"sl=b&ss=lhusgj0j&tt=2kvu&z=1&dm=asos.com&si=3b554133-7a94-4a6e-95f1-2e719489115b&bcn=%2F%2F684d0d46.akstat.io%2F&ld=cwyg&nu=2sbpx1rk&cl=dp7s"',
      's_sq': 'asoscomprod%3D%2526c.%2526a.%2526activitymap.%2526page%253Ddesktop%252520row%25257Ccategory%252520page%252520pagination%25257C8409%252520page%2525202%2526link%253DLOAD%252520MORE%2526region%253Dplp%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c',
  }

  headers = {
      'authority': 'www.asos.com',
      'accept': 'application/json, text/plain, */*',
      'accept-language': 'en-US,en;q=0.9',
      'asos-c-name': '@asosteam/asos-web-product-listing-page',
      'asos-c-plat': 'web',
      'asos-c-ver': '1.2.0-d7bef89a42ea-8963',
      'asos-cid': '8bbe08b5-fffd-4798-8d5c-939d5bf4b4af',
      # 'cookie': 'asosAffiliate=affiliateId=17295; browseCountry=IN; s_ecid=MCMID%7C36348881506979124243080375041297881048; browseCurrency=GBP; browseLanguage=en-GB; browseSizeSchema=UK; storeCode=ROW; currency=1; featuresId=add09538-59a0-4fa6-8f7f-ca531bef34bf; _gcl_au=1.1.1976705817.1684424031; bt_stdstatus=NOTSTUDENT; stc-welcome-message=cappedPageCount=2; floor=1001; asos=PreferredSite=&currencyid=1&currencylabel=GBP&customerguid=b491a3e6606e47db8edb1abf9b54f05e&topcatid=1001; _cs_c=0; FPID=FPID2.2.55wejNiJBlk6Fjma5ucw%2Fvvp23W6qvL6uTzByYWrvjA%3D.1684424040; FPAU=1.1.1976705817.1684424031; _gid=GA1.2.2055111386.1684424054; __gads=ID=9c6f643b4ee7c6ba:T=1684424534:S=ALNI_MYCZva9KxAitInZFVy_700g-uExxw; fita.sid.asos=ax09Qz461ZBFRGcMmoIZOeGWfCgIwlUT; geocountry=IN; bm_sz=6F4E5D165BA708EEEC4011BA861BCA66~~4470576~3753525; asos-b-sdv629=ornjx7v-36; AMCVS_C0137F6A52DEAFCC0A490D4C%40AdobeOrg=1; asos-perx=b491a3e6606e47db8edb1abf9b54f05e||204f4c0f389049b2b24dc76eac6ada44; s_cc=true; FPLC=S%2F0sQv30QhK5inMdjhyDMHVjSgBkk5C4hGiZ%2FgdxKFkRtVIY374OncSqDkxoitBs9LM1lOPyLJp5l%2FbpDoKUzj7kJ7Wg2XfiP6twIJd9pwSX2D%2FVhdQ%2FkEYdCWH98Q%3D%3D; __gpi=UID=00000c07c4305ff8:T=1684424534:RT=1684503731:S=ALNI_MaVBVf5JJhPC5Y43gQd2g1BsZS52g; siteChromeVersion=au=12&com=12&de=12&dk=12&es=12&fr=12&it=12&nl=12&pl=12&roe=12&row=12&ru=12&se=12&us=12; keyStoreDataversion=ornjx7v-36; AMCV_C0137F6A52DEAFCC0A490D4C%40AdobeOrg=-1303530583%7CMCMID%7C36348881506979124243080375041297881048%7CMCAAMLH-1685119361%7C12%7CMCAAMB-1685119361%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCCIDH%7C0%7CMCOPTOUT-1684521761s%7CNONE%7CvVersion%7C3.3.0%7CMCAID%7CNONE; _s_fpv=true; _abck=842C1A26B79B39231A32A645DB911DDA~0~...~-1~-1~1684518051; _cs_mk_aa=0.7674853226137397_1684514587414; bm_mi=14AA33748C7244C5D3F97E0D33529145~~1; bm_sv=60C5FB35221D7619DE4DBD93420EAA2C~YAAQpLxWaBrBBAaIAQAAo+LqNBNI+MXPjPYpkk63FNovbqLTagoTDpfQ2ImULZvjcgQPz0apV19GDiS3df44TJVJ4StBT479BaSq3Cr5OewSBiYJWzGU4ey6AG0wRd1fLTY1cjjKCaqWBDYcPIXg0a8tBziQonygxvTO0U119kjVeCLoJAXhlDRWl68177Fm//YGODLMXYCygIxpUP/pOnxQziUMtN6nRPdsIe3xeTPqGoGr6mihya13a3MgCg==~1; OptanonConsent=isGpcEnabled=0&datestamp=Fri+May+19+2023+22%3A20%3A49+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&landingPath=https%3A%2F%2Fwww.asos.com%2Fmen%2Fsale%2Fcat%2F%3Fcid%3D8409&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1; _ga=GA1.2.106621371.1684424040; plp_columsCount=threeColumns; _ga_1JR0QCFRSY=GS1.1.1684514589.6.1.1684515130.45.0.0; ak_bmsc=C08DDC448B069F1F58F4044A8B9DB46E~000000000000000000000000000000~...; _cs_id=3590dd81-5708-aaac-8054-eebeb4055e8e.1684424039.6.1684515131.1684514589.1628755191.1718588039920; _cs_s=9.0.0.1684516931985; s_pers=%20s_vnum%3D1685557800193%2526vn%253D7%7C1685557800193%3B%20gpv_eVar230%3Dno%2520value%7C1684516410299%3B%20gpv_eVar234%3Dno%2520value%7C1684516410306%3B%20gpv_p6%3D%2520%7C1684516837095%3B%20s_nr%3D1684515057951-Repeat%7C1716051057951%3B%20gpv_e47%3Dno%2520value%7C1684516857960%3B%20gpv_p10%3Ddesktop%2520row%257Ccategory%2520page%257C8409%2520refined%7C1684516857974%3B%20gpv_e231%3Dfa43ec7e-eaae-419d-8571-5880f210b75b%7C1684516932177%3B%20eVar225%3D7%7C1684516932253%3B%20s_invisit%3Dtrue%7C1684516932263%3B%20visitCount%3D7%7C1684516932270%3B; RT="sl=b&ss=lhusgj0j&tt=2kvu&z=1&dm=asos.com&si=3b554133-7a94-4a6e-95f1-2e719489115b&bcn=%2F%2F684d0d46.akstat.io%2F&ld=cwyg&nu=2sbpx1rk&cl=dp7s"; s_sq=asoscomprod%3D%2526c.%2526a.%2526activitymap.%2526page%253Ddesktop%252520row%25257Ccategory%252520page%252520pagination%25257C8409%252520page%2525202%2526link%253DLOAD%252520MORE%2526region%253Dplp%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c',
      'referer': 'https://www.asos.com/men/sale/cat/?cid=8409&page=3',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
  }

  params = {
      'offset': str(i),
      'store': 'ROW',
      'lang': 'en-GB',
      'currency': 'GBP',
      'rowlength': '3',
      'channel': 'desktop-web',
      'country': 'IN',
      'keyStoreDataversion': 'ornjx7v-36',
      'limit': '72',
  }

  response = requests.get(
      'https://www.asos.com/api/product/search/v2/categories/8409',
      params=params,
      cookies=cookies,
      headers=headers,
  )
#response.json()
  result=response.json()
  product_items=result['products']
    
  for items in product_items:
      product_name.append(items['name'])
      category.append("men_apparels")
      current_price.append(items['price']['current']['text'])
      brand_name.append(items['brandName'])
      Url.append(website_link + items['url'])

# %%
product_items[0]
# Out:
# {'id': 201231537,
#  'name': 'ASOS DESIGN super skinny wedding waistcoat in linen mix pale pink pow check',
#  'price': {'current': {'value': 19.2, 'text': '£19.20'},
#   'previous': {'value': 32.0, 'text': '£32.00'},
#   'rrp': {'value': None, 'text': ''},
#   'isMarkedDown': True,
#   'isOutletPrice': False,
#   'currency': 'GBP'},
#  'colour': '',
#  'colourWayId': 201231538,
#  'brandName': 'ASOS DESIGN',
#  'hasVariantColours': False,
#  'hasMultiplePrices': False,
#  'groupId': None,
#  'productCode': 110898899,
#  'productType': 'Product',
#  'url': 'asos-design/asos-design-super-skinny-wedding-waistcoat-in-linen-mix-pale-pink-pow-check/prd/201231537?colourWayId=201231538',
#  'imageUrl': 'images.asos-media.com/products/asos-design-super-skinny-wedding-waistcoat-in-linen-mix-pale-pink-pow-check/201231537-1-pink',
#  'additionalImageUrls': ['images.asos-media.com/products/asos-design-super-skinny-wedding-waistcoat-in-linen-mix-pale-pink-pow-check/201231537-2',
# ...

# %%
product_items[0]['name']
product_items[0]['brandName']
product_items[0]['price']['current']['text']
# Out:
# '£19.20'

# %%
asos_df=pd.DataFrame({'product_name':product_name, 'category':category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
asos_df
# Out:
#                                            product_name      category   price  \
# 0     Devil's Advocate bright puppytooth print overcoat  men_apparels  £58.50
# 1     Topman fluffy knitted jumper with all over che...  men_apparels  £23.50
# 2      Bolongaro Trevor smart trouser in navy pinstripe  men_apparels  £24.00
# 3     adidas Originals Hyperturf trainers in triple ...  men_apparels  £63.00
# 4     ADPT oversized cotton poplin shirt with pocket...  men_apparels  £15.50
# ...                                                 ...           ...     ...
# 2155           ASOS DESIGN super skinny chinos in black  men_apparels  £18.00
# 2156  ASOS DESIGN slim fit sateen shirt with shawl c...  men_apparels  £22.50
# 2157  New Era New York Yankees wordmark t-shirt in w...  men_apparels  £21.00
# 2158  ASOS DESIGN relaxed long sleeve t-shirt in bla...  men_apparels  £14.50
# 2159                         adidas Yoga shorts in navy  men_apparels  £28.50
#
# ...

# %% [markdown]
# #Web scraping women cloths from H&M

# %%
#Repeating the same steps mentioned above to scrape ladies_top

import requests
import pandas as pd

product_name=[]
category=[]
current_price=[]
brand_name=[]
Url= []

website_link='https://www2.hm.com/'

#Iterating over 40 pages with 36 items per page
for i in range (0,1440,36):

  cookies = {
      'preshoppingUser': 'false',
      'HMCORP_locale': 'en_IN',
      'HMCOUNTRY_name': 'India',
      'HMCORP_locale_autoassigned': 'false',
      'OptanonAlertBoxClosed': '2023-05-18T21:23:23.440Z',
      'agCookie': 'ec369879-1e8c-46ba-bce2-20ce42a8729a',
      'hm-india-cart': '13fdfc30-eee8-4130-a86b-4384b73c4c95',
      'hm-india-favourites': '""',
      'akainst': 'APAC',
      'bm_sz': '3151BE2E9C91D631419F557D7E326884~~3683377~4277809',
      'INGRESSCOOKIE': '1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc',
      'JSESSIONID': '3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw',
      'userCookie': '##eyJjYXJ0Q291bnQiOjB9##',
      'AKA_A2': 'A',
      'bm_mi': '8E1B3587E24C601AA6608A396968BD73~~1',
      'ak_bmsc': '1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A48+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'akamref': 'en_in',
      'akavpau_www2_en_in': '1684524409~id=b99809e6694d78cc2fe087009fdb0f31',
      'RT': '"z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=f&tt=1rbr&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3&ld=zlpz"',
      '_abck': '557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772',
      'bm_sv': '0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF4x1OwKIAQAAizd2NRMpe1S0n/CO8skpHvPvp8JveDYZjnFCd8T3gHmmldOoynRklDSIXayrpAxr7LdNV7Jg3Nqe3hPSTRVeI0pt2gQ6dF3JpWRszRNwFC0rU1Yhvv5IF8U+tfoi0+ugrocHRF8c1O/K6LjRSMam9OMY8ebqWlhGns1t+f1DPJUMGKos7RnFr9Jno4bNtkpcc0yitK2zR/yExmGnqe5YCe/hvUNlGMfFMCL4v2Me~1',
      'utag_main': 'v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:180$_ss:0$_st:1684526081169$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:16%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20TOPS%2FTOPS%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Tops%20%3A%20Viewall%3Bexp-1684527766483$cart_active:No%3Bexp-session',
  }

  headers = {
      'authority': 'www2.hm.com',
      'accept': 'application/json, text/javascript, */*; q=0.01',
      'accept-language': 'en-US,en;q=0.9',
      # 'cookie': 'preshoppingUser=false; HMCORP_locale=en_IN; HMCOUNTRY_name=India; HMCORP_locale_autoassigned=false; OptanonAlertBoxClosed=2023-05-18T21:23:23.440Z; agCookie=ec369879-1e8c-46ba-bce2-20ce42a8729a; hm-india-cart=13fdfc30-eee8-4130-a86b-4384b73c4c95; hm-india-favourites=""; akainst=APAC; bm_sz=3151BE2E9C91D631419F557D7E326884~~3683377~4277809; INGRESSCOOKIE=1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc; JSESSIONID=3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw; userCookie=##eyJjYXJ0Q291bnQiOjB9##; AKA_A2=A; bm_mi=8E1B3587E24C601AA6608A396968BD73~~1; ak_bmsc=1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A48+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; akamref=en_in; akavpau_www2_en_in=1684524409~id=b99809e6694d78cc2fe087009fdb0f31; RT="z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=f&tt=1rbr&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3&ld=zlpz"; _abck=557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772; bm_sv=0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF4x1OwKIAQAAizd2NRMpe1S0n/CO8skpHvPvp8JveDYZjnFCd8T3gHmmldOoynRklDSIXayrpAxr7LdNV7Jg3Nqe3hPSTRVeI0pt2gQ6dF3JpWRszRNwFC0rU1Yhvv5IF8U+tfoi0+ugrocHRF8c1O/K6LjRSMam9OMY8ebqWlhGns1t+f1DPJUMGKos7RnFr9Jno4bNtkpcc0yitK2zR/yExmGnqe5YCe/hvUNlGMfFMCL4v2Me~1; utag_main=v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:180$_ss:0$_st:1684526081169$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:16%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20TOPS%2FTOPS%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Tops%20%3A%20Viewall%3Bexp-1684527766483$cart_active:No%3Bexp-session',
      'referer': 'https://www2.hm.com/en_in/women/shop-by-product/tops.html?sort=stock&image-size=small&image=model&offset=0&page-size=108',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
      'x-requested-with': 'XMLHttpRequest',
  }

  params = {
      'sort': 'stock',
      'image-size': 'small',
      'image': 'model',
      'offset': str(i),
      'page-size': '36',
  }

  response = requests.get(
      'https://www2.hm.com/en_in/women/shop-by-product/tops/_jcr_content/main/productlisting.display.json',
      params=params,
      cookies=cookies,
      headers=headers,
  )


  result=response.json()
  product_items=result['products']

  for items in product_items:
      product_name.append(items['title'])
      category.append('Ladies_dress')
      current_price.append(items['price'])
      brand_name.append(items['brandName'])
      Url.append(website_link + items['link'])

# %%
hm_df=pd.DataFrame({'product_name':product_name, 'category': category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
hm_df
# Out:
#                    product_name      category        price Brand  \
# 0              Cropped vest top  Ladies_dress    Rs.799.00   H&M
# 1              Cut-out crop top  Ladies_dress    Rs.799.00   H&M
# 2      Vest top with lace trims  Ladies_dress    Rs.699.00   H&M
# 3              Puff-sleeved top  Ladies_dress    Rs.999.00   H&M
# 4              Cropped vest top  Ladies_dress    Rs.799.00   H&M
# ...                         ...           ...          ...   ...
# 1430            Rib-knit jumper  Ladies_dress  Rs.2,999.00   H&M
# 1431      Ribbed halterneck top  Ladies_dress  Rs.1,299.00   H&M
# 1432       Cropped sweater vest  Ladies_dress    Rs.799.00   H&M
# 1433     Knitted sleeveless top  Ladies_dress    Rs.999.00   H&M
# 1434  Cropped ribbed velour top  Ladies_dress  Rs.1,299.00   H&M
#
#                                                     Url
# 0     https://www2.hm.com//en_in/productpage.1049251...
# 1     https://www2.hm.com//en_in/productpage.1073101...
# ...

# %%
hm_df.Url[0]
# Out:
# 'https://www2.hm.com//en_in/productpage.1049251001.html'

# %%
#Repeating the same steps mentioned above to scrape ladies_trousers

import requests
import pandas as pd

product_name=[]
category=[]
current_price=[]
brand_name=[]
Url= []

website_link='https://www2.hm.com'

#Iterating over 40 pages with 36 items per page
for i in range (0,400,36):

  cookies = {
      'preshoppingUser': 'false',
      'HMCORP_locale': 'en_IN',
      'HMCOUNTRY_name': 'India',
      'HMCORP_locale_autoassigned': 'false',
      'OptanonAlertBoxClosed': '2023-05-18T21:23:23.440Z',
      'agCookie': 'ec369879-1e8c-46ba-bce2-20ce42a8729a',
      'hm-india-cart': '13fdfc30-eee8-4130-a86b-4384b73c4c95',
      'hm-india-favourites': '""',
      'akainst': 'APAC',
      'bm_sz': '3151BE2E9C91D631419F557D7E326884~~3683377~4277809',
      'INGRESSCOOKIE': '1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc',
      'JSESSIONID': '3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw',
      'userCookie': '##eyJjYXJ0Q291bnQiOjB9##',
      'AKA_A2': 'A',
      'bm_mi': '8E1B3587E24C601AA6608A396968BD73~~1',
      'ak_bmsc': '1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'utag_main': 'v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:217$_ss:0$_st:1684526657534$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:22%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20TROUSERS%2FTROUSERS%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Trousers%20%3A%20Viewall%3Bexp-1684528457549$cart_active:No%3Bexp-session',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+01%3A04%3A20+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'akamref': 'en_in',
      'akavpau_www2_en_in': '1684525101~id=ba939c2a8f8be659904e952b4c38b109',
      '_abck': '557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772',
      'bm_sv': '0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF3aMOwKIAQAA0ZaBNRNJN+VOljMM2M0jy53aNtw0C/e5MrxqQCUdz9zpR8P1e5E5F7x2rL4+E45QD7BKR/Iw7lZfgpo/HVGbUlyLIqRn/GXaLczq05na+IF61L3HixEp/k9cPqzZ0wOdiCRoFNzQr7spg7Y8a3YuMg2lNTj00G4EkKovZb1d3MQiFeOHiacWVdPdkkcHbskHqldhe+oQNpo1y0uz4NvUrot4+diNcELcuGpZ0qN5~1',
      'RT': '"z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=k&tt=2eg1&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3"',
  }

  headers = {
      'authority': 'www2.hm.com',
      'accept': 'application/json, text/javascript, */*; q=0.01',
      'accept-language': 'en-US,en;q=0.9',
      # 'cookie': 'preshoppingUser=false; HMCORP_locale=en_IN; HMCOUNTRY_name=India; HMCORP_locale_autoassigned=false; OptanonAlertBoxClosed=2023-05-18T21:23:23.440Z; agCookie=ec369879-1e8c-46ba-bce2-20ce42a8729a; hm-india-cart=13fdfc30-eee8-4130-a86b-4384b73c4c95; hm-india-favourites=""; akainst=APAC; bm_sz=3151BE2E9C91D631419F557D7E326884~~3683377~4277809; INGRESSCOOKIE=1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc; JSESSIONID=3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw; userCookie=##eyJjYXJ0Q291bnQiOjB9##; AKA_A2=A; bm_mi=8E1B3587E24C601AA6608A396968BD73~~1; ak_bmsc=1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; utag_main=v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:217$_ss:0$_st:1684526657534$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:22%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20TROUSERS%2FTROUSERS%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Trousers%20%3A%20Viewall%3Bexp-1684528457549$cart_active:No%3Bexp-session; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+01%3A04%3A20+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; akamref=en_in; akavpau_www2_en_in=1684525101~id=ba939c2a8f8be659904e952b4c38b109; _abck=557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772; bm_sv=0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF3aMOwKIAQAA0ZaBNRNJN+VOljMM2M0jy53aNtw0C/e5MrxqQCUdz9zpR8P1e5E5F7x2rL4+E45QD7BKR/Iw7lZfgpo/HVGbUlyLIqRn/GXaLczq05na+IF61L3HixEp/k9cPqzZ0wOdiCRoFNzQr7spg7Y8a3YuMg2lNTj00G4EkKovZb1d3MQiFeOHiacWVdPdkkcHbskHqldhe+oQNpo1y0uz4NvUrot4+diNcELcuGpZ0qN5~1; RT="z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=k&tt=2eg1&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3"',
      'referer': 'https://www2.hm.com/en_in/women/shop-by-product/trousers.html?sort=stock&image-size=small&image=model&offset=0&page-size=36',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
      'x-requested-with': 'XMLHttpRequest',
  }

  params = {
      'sort': 'stock',
      'image-size': 'small',
      'image': 'model',
      'offset': str(i),
      'page-size': '36',
  }

  response = requests.get(
      'https://www2.hm.com/en_in/women/shop-by-product/trousers/_jcr_content/main/productlisting.display.json',
      params=params,
      cookies=cookies,
      headers=headers,
  )


  result=response.json()
  product_items=result['products']

  for items in product_items:
      product_name.append(items['title'])
      category.append('Ladies_dress')
      current_price.append(items['price'])
      brand_name.append(items['brandName'])
      Url.append(website_link + items['link'])

# %%
hm2_df=pd.DataFrame({'product_name':product_name, 'category': category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
hm2_df
# Out:
#                       product_name      category        price Brand  \
# 0    Linen-blend tailored trousers  Ladies_dress  Rs.4,999.00   H&M
# 1    Linen-blend tailored trousers  Ladies_dress  Rs.4,999.00   H&M
# 2           Crêpe pull-on trousers  Ladies_dress  Rs.1,399.00   H&M
# 3                Tailored trousers  Ladies_dress  Rs.2,299.00   H&M
# 4                  Flared trousers  Ladies_dress  Rs.2,299.00   H&M
# ..                             ...           ...          ...   ...
# 427                  Linen joggers  Ladies_dress  Rs.2,299.00   H&M
# 428          Ankle-length trousers  Ladies_dress  Rs.1,999.00   H&M
# 429                  Wide trousers  Ladies_dress  Rs.1,399.00   H&M
# 430           Motif-detail joggers  Ladies_dress  Rs.1,999.00   H&M
# 431   Embroidered pull-on trousers  Ladies_dress  Rs.3,999.00   H&M
#
#                                                    Url
# 0    https://www2.hm.com/en_in/productpage.11829010...
# ...

# %%
hm2_df.Url[0]
# Out:
# 'https://www2.hm.com/en_in/productpage.1182901002.html'

# %%
#Repeating the same steps mentioned above to scrape ladies_full_dress

import requests
import pandas as pd

product_name=[]
category=[]
current_price=[]
brand_name=[]
Url= []

website_link='https://www2.hm.com'

#Iterating over 40 pages with 36 items per page
for i in range (0,400,36):

  import requests

  cookies = {
      'preshoppingUser': 'false',
      'HMCORP_locale': 'en_IN',
      'HMCOUNTRY_name': 'India',
      'HMCORP_locale_autoassigned': 'false',
      'OptanonAlertBoxClosed': '2023-05-18T21:23:23.440Z',
      'agCookie': 'ec369879-1e8c-46ba-bce2-20ce42a8729a',
      'hm-india-cart': '13fdfc30-eee8-4130-a86b-4384b73c4c95',
      'hm-india-favourites': '""',
      'akainst': 'APAC',
      'bm_sz': '3151BE2E9C91D631419F557D7E326884~~3683377~4277809',
      'INGRESSCOOKIE': '1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc',
      'JSESSIONID': '3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw',
      'userCookie': '##eyJjYXJ0Q291bnQiOjB9##',
      'bm_mi': '8E1B3587E24C601AA6608A396968BD73~~1',
      'ak_bmsc': '1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'akavpau_www2_en_in': '1684526294~id=46ada6542ec9603d5d0ba86715dc184e',
      'akamref': '',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+May+20+2023+01%3A24%3A20+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0',
      'RT': '"z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=m&tt=2qez&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3&ld=245yk"',
      'utag_main': 'v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:242$_ss:0$_st:1684527872513$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:27%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20DRESSES%2FDRESSES%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Dresses%20%3A%20Viewall%3Bexp-1684529655681$cart_active:No%3Bexp-session',
      '_abck': '557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772',
      'bm_sv': '0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF1m4OwKIAQAAKOGTNRN6zKtt9FJr8fxRY/ey0+jKmS8YLf1qXDqeStxtIpD9EU+5MSLETbHnLXNqyAaktiMTaL9iJRuuWlfsvA14+zykV1cbFCUtr2aNlt8SSUQOrTOZ3s6TGwhGpc4BgwWnSctbZRjJC428uNn0vRj0fUpSED1xoQ2QZZQ3ZYsI29LOjjl7A6ufwvAIvbi9twIlo1dlxEjuxTVFBphvNJYU1TPewt0epcE1SpPP~1',
  }

  headers = {
      'authority': 'www2.hm.com',
      'accept': 'application/json, text/javascript, */*; q=0.01',
      'accept-language': 'en-US,en;q=0.9',
      # 'cookie': 'preshoppingUser=false; HMCORP_locale=en_IN; HMCOUNTRY_name=India; HMCORP_locale_autoassigned=false; OptanonAlertBoxClosed=2023-05-18T21:23:23.440Z; agCookie=ec369879-1e8c-46ba-bce2-20ce42a8729a; hm-india-cart=13fdfc30-eee8-4130-a86b-4384b73c4c95; hm-india-favourites=""; akainst=APAC; bm_sz=3151BE2E9C91D631419F557D7E326884~~3683377~4277809; INGRESSCOOKIE=1684522237.927.622193.846548|7bbf721d92a09b08c42eb8596390c8cc; JSESSIONID=3872C6F969FCAB397E39ADD906E096576259B5F872758701AC31501247AF56832225E62A797DC6E3CA34592A6A8D19DF5CD34887F22A9BDE484F0E80A0929343.hybris-ecm-web-7bbd6ddd9-xnvqw; userCookie=##eyJjYXJ0Q291bnQiOjB9##; bm_mi=8E1B3587E24C601AA6608A396968BD73~~1; ak_bmsc=1FB26A728E2368B880B7E56FD0705239~000000000000000000000000000000~...; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+00%3A52%3A42+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; akavpau_www2_en_in=1684526294~id=46ada6542ec9603d5d0ba86715dc184e; akamref=; OptanonConsent=isGpcEnabled=0&datestamp=Sat+May+20+2023+01%3A24%3A20+GMT%2B0530+(India+Standard+Time)&version=202211.1.0&isIABGlobal=false&hosts=&consentId=66f1ab79-ea8b-4b83-b9e2-17f33803562c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; RT="z=1&dm=hm.com&si=1ff8ccb4-04d0-4f33-bcfb-c95f51a16dc3&ss=lhux7hy7&sl=m&tt=2qez&bcn=%2F%2F684d0d48.akstat.io%2F&obo=3&ld=245yk"; utag_main=v_id:018830bee5c600a33814153319000506f00240670086e$_sn:8$_se:242$_ss:0$_st:1684527872513$c_consent:C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0$ses_id:1684522300128%3Bexp-session$_pn:27%3Bexp-session$ses_id_r:s_7147485501141890.1684522300128%3Bexp-session$segment:normal%3Bexp-session$prevpage:%2FLADIES%2FSHOPBYPRODUCT%20%3A%20DRESSES%2FDRESSES%20%3A%20VIEWALL%2FVIEW_ALL%2FLadies%20%3A%20Shopbyproduct%20%3A%20Dresses%20%3A%20Viewall%3Bexp-1684529655681$cart_active:No%3Bexp-session; _abck=557FF8D0FD49B789DACBE5B099E4D5B7~0~~-1~-1~1684525772; bm_sv=0C49A227F5AA3225C1C30A3E346EFFAA~YAAQlJUvF1m4OwKIAQAAKOGTNRN6zKtt9FJr8fxRY/ey0+jKmS8YLf1qXDqeStxtIpD9EU+5MSLETbHnLXNqyAaktiMTaL9iJRuuWlfsvA14+zykV1cbFCUtr2aNlt8SSUQOrTOZ3s6TGwhGpc4BgwWnSctbZRjJC428uNn0vRj0fUpSED1xoQ2QZZQ3ZYsI29LOjjl7A6ufwvAIvbi9twIlo1dlxEjuxTVFBphvNJYU1TPewt0epcE1SpPP~1',
      'referer': 'https://www2.hm.com/en_in/women/shop-by-product/dresses.html?sort=stock&image-size=small&image=model&offset=0&page-size=36',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
      'x-requested-with': 'XMLHttpRequest',
  }

  params = {
      'sort': 'stock',
      'image-size': 'small',
      'image': 'model',
      'offset': str(i),
      'page-size': '36',
  }

  response = requests.get(
      'https://www2.hm.com/en_in/women/shop-by-product/dresses/_jcr_content/main/productlisting.display.json',
      params=params,
      cookies=cookies,
      headers=headers,
  )

  result=response.json()
  product_items=result['products']

  for items in product_items:
      product_name.append(items['title'])
      category.append('Ladies_dress')
      current_price.append(items['price'])
      brand_name.append(items['brandName'])
      Url.append(website_link + items['link'])

# %%
hm3_df=pd.DataFrame({'product_name':product_name, 'category': category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
hm3_df
# Out:
#                       product_name      category        price Brand  \
# 0     Oversized one-shoulder dress  Ladies_dress  Rs.1,999.00   H&M
# 1               Crochet-look dress  Ladies_dress  Rs.2,999.00   H&M
# 2            Flounce-trimmed dress  Ladies_dress  Rs.2,299.00   H&M
# 3           Embellished mini dress  Ladies_dress  Rs.5,999.00   H&M
# 4                Jersey slip dress  Ladies_dress  Rs.1,299.00   H&M
# ..                             ...           ...          ...   ...
# 427     Smocked-waist jersey dress  Ladies_dress  Rs.1,499.00   H&M
# 428          Tie-detail wrap dress  Ladies_dress  Rs.2,299.00   H&M
# 429  Balloon-sleeved smocked dress  Ladies_dress  Rs.2,699.00   H&M
# 430         3-pack strappy dresses  Ladies_dress  Rs.1,999.00   H&M
# 431      Textured-weave slip dress  Ladies_dress  Rs.3,999.00   H&M
#
#                                                    Url
# 0    https://www2.hm.com/en_in/productpage.11883870...
# ...

# %%
hm3_df.Url[0]
# Out:
# 'https://www2.hm.com/en_in/productpage.1188387001.html'

# %% [markdown]
# #Web Scraping mens innerwear from Tata Cliq

# %%
#Repeating the same steps mentioned above

import requests
import pandas as pd

product_name=[]
category=[]
current_price=[]
brand_name=[]
Url= []
website_link='https://www.tatacliq.com'

#Iterating over 550 pages with 40 products per page
for i in range(0, 2000, 40):

  headers = {
      'authority': 'searchbff.tatacliq.com',
      'accept': '*/*',
      'accept-language': 'en-US,en;q=0.9',
      'mode': 'no-cors',
      'origin': 'https://www.tatacliq.com',
      'referer': 'https://www.tatacliq.com/',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-site',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
  }

  params = {
      'searchText': ':relevance:category:MSH1114:inStockFlag:true',
      'isKeywordRedirect': 'true',
      'isKeywordRedirectEnabled': 'true',
      'channel': 'WEB',
      'isMDE': 'true',
      'isTextSearch': 'false',
      'isFilter': 'false',
      'qc': 'false',
      'test': 'invizbff.qpsv3-inviz.bs',
      'offset': str(i),
      'mcvid': '36080478327616186643088443667790557016',
      'customerId': '',
      'isSuggested': 'false',
      'isPwa': 'true',
      'pageSize': '40',
      'typeID': 'all',
  }

  response = requests.get('https://searchbff.tatacliq.com/products/mpl/search', params=params, headers=headers)
  result=response.json()
  product_items=result['searchresult']
  
  for items in product_items:
      product_name.append(items['productname'])
      category.append('Mens_innerwear')
      current_price.append(items['price']['sellingPrice']['formattedValueNoDecimal'])
      brand_name.append(items['brandname'])
      Url.append(website_link + items['webURL'])

# %%
tata_mensinerwear_df=pd.DataFrame({'product_name':product_name, 'category': category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
tata_mensinerwear_df
# Out:
#                                            product_name        category price  \
# 0                Jockey Grey Comfort Fit Printed Trunks  Mens_innerwear  ₹429
# 1     Jockey Deep Olive Regular Fit Boxer Briefs - P...  Mens_innerwear  ₹598
# 2        Puma Multicolor Regular Fit Trunks - Pack of 2  Mens_innerwear  ₹769
# 3     WES Lounge by Westside Light Mauve Trunks Pack...  Mens_innerwear  ₹799
# 4           U.S. Polo Assn. Assorted Trunks - Pack of 2  Mens_innerwear  ₹624
# ...                                                 ...             ...   ...
# 1995               Jockey Carbon Black Vest - Pack of 2  Mens_innerwear  ₹658
# 1996  Jockey Grey Melange Regular Fit Trunks - Pack ...  Mens_innerwear  ₹578
# 1997  Dollar Bigboss Assorted Color Cotton Under Ela...  Mens_innerwear  ₹599
# 1998            ONN White Regular Fit Vests - Pack Of 2  Mens_innerwear  ₹450
# 1999                    Jockey Black Regular Fit Trunks  Mens_innerwear  ₹349
#
# ...

# %% [markdown]
# #Web scraping women nigwear from Tata Cliq

# %%
#Repeating the same steps mentioned above

import requests
import pandas as pd

product_name=[]
category=[]
current_price=[]
brand_name=[]
Url= []
website_link='https://www.tatacliq.com'

#Iterating over 50 pages with 40 products per page
for i in range(0, 2000, 40):

  headers = {
      'authority': 'searchbff.tatacliq.com',
      'accept': '*/*',
      'accept-language': 'en-US,en;q=0.9',
      'mode': 'no-cors',
      'origin': 'https://www.tatacliq.com',
      'referer': 'https://www.tatacliq.com/',
      'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-site',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
  }

  params = {
      'searchText': ':relevance:category:MSH1014:inStockFlag:true',
      'isKeywordRedirect': 'false',
      'isKeywordRedirectEnabled': 'false',
      'channel': 'WEB',
      'isMDE': 'true',
      'isTextSearch': 'false',
      'isFilter': 'false',
      'qc': 'false',
      'test': 'invizbff.qpsv3-inviz.bs',
      'offset': str(i),
      'mcvid': '36080478327616186643088443667790557016',
      'customerId': '',
      'isSuggested': 'false',
      'isPwa': 'true',
      'pageSize': '40',
      'typeID': 'all',
  }

  response = requests.get('https://searchbff.tatacliq.com/products/mpl/search', params=params, headers=headers)

  result=response.json()
  product_items=result['searchresult']
  
  for items in product_items:
      product_name.append(items['productname'])
      category.append('Womens_nightwear')
      current_price.append(items['price']['sellingPrice']['formattedValueNoDecimal'])
      brand_name.append(items['brandname'])
      Url.append(website_link + items['webURL'])

# %%
tata_womennightwear_df=pd.DataFrame({'product_name':product_name, 'category': category, 'price': current_price, 'Brand': brand_name, 'Url': Url})
tata_womennightwear_df
# Out:
#                                            product_name          category  \
# 0     Dreamz by Pantaloons Lilac Cotton Graphic Prin...  Womens_nightwear
# 1       Enamor Black Non Wired Non Padded Minimizer Bra  Womens_nightwear
# 2                Triumph Red Geometric Print Padded Bra  Womens_nightwear
# 3     Triumph Minimizer 21 Wireless Non Padded Comfo...  Womens_nightwear
# 4     Wacoal Mystique Padded Non-Wired 3/4Th Cup Lac...  Womens_nightwear
# ...                                                 ...               ...
# 1995  Jockey 1523 Assorted High-Waist Hipster Panty ...  Womens_nightwear
# 1996   Triumph Pink Non-Wired Full Coverage T-Shirt Bra  Womens_nightwear
# 1997        Cottinfab Yellow Printed Kaftan Night Dress  Womens_nightwear
# 1998    Wunderlove Sleepwear by Westside Anthra T-Shirt  Womens_nightwear
# 1999  Amante Multicolor Cotton Hipster Panty (Pack o...  Womens_nightwear
#
#       price                 Brand  \
# 0      ₹380  Dreamz by Pantaloons
# ...

# %%
#Concatinating all dataframes into a single one

master_df = pd.concat([asos_df, hm_df, tata_mensinerwear_df, tata_womennightwear_df]) 
master_df
# Out:
#                                            product_name          category  \
# 0     Devil's Advocate bright puppytooth print overcoat      men_apparels
# 1     Topman fluffy knitted jumper with all over che...      men_apparels
# 2      Bolongaro Trevor smart trouser in navy pinstripe      men_apparels
# 3     adidas Originals Hyperturf trainers in triple ...      men_apparels
# 4     ADPT oversized cotton poplin shirt with pocket...      men_apparels
# ...                                                 ...               ...
# 1995  Jockey 1523 Assorted High-Waist Hipster Panty ...  Womens_nightwear
# 1996   Triumph Pink Non-Wired Full Coverage T-Shirt Bra  Womens_nightwear
# 1997        Cottinfab Yellow Printed Kaftan Night Dress  Womens_nightwear
# 1998    Wunderlove Sleepwear by Westside Anthra T-Shirt  Womens_nightwear
# 1999  Amante Multicolor Cotton Hipster Panty (Pack o...  Womens_nightwear
#
#        price             Brand  \
# 0     £58.50   Devils Advocate
# ...

# %%
#Concatenating all the above dataframes 

master_df2 = pd.concat([asos_df, hm_df, hm2_df, hm3_df, tata_mensinerwear_df, tata_womennightwear_df], ignore_index=True ) 
master_df2
# Out:
#                                            product_name          category  \
# 0     Devil's Advocate bright puppytooth print overcoat      men_apparels
# 1     Topman fluffy knitted jumper with all over che...      men_apparels
# 2      Bolongaro Trevor smart trouser in navy pinstripe      men_apparels
# 3     adidas Originals Hyperturf trainers in triple ...      men_apparels
# 4     ADPT oversized cotton poplin shirt with pocket...      men_apparels
# ...                                                 ...               ...
# 8454  Jockey 1523 Assorted High-Waist Hipster Panty ...  Womens_nightwear
# 8455   Triumph Pink Non-Wired Full Coverage T-Shirt Bra  Womens_nightwear
# 8456        Cottinfab Yellow Printed Kaftan Night Dress  Womens_nightwear
# 8457    Wunderlove Sleepwear by Westside Anthra T-Shirt  Womens_nightwear
# 8458  Amante Multicolor Cotton Hipster Panty (Pack o...  Womens_nightwear
#
#        price             Brand  \
# 0     £58.50   Devils Advocate
# ...

# %%
#master_df.to_csv('clothing_data.csv')

# %%
#Saving the dataframe to csv file
master_df2.to_csv('clothing_data_new.csv', index=False)
